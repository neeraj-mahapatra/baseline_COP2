# %%
import pandas as pd
import random

# random.seed()  # Reseed the generator for more randomness

alpha = 0.4  
beta = 0.6   
purchasing_power = 100.0
k = 7   # size of bundles
C_max = 100.0  
theta = 1  
gamma = 0.25  
delta = 0.75
n_categories = 7  # max number of categories allowed per bundle
num_bundles = 2 # number of bundles
input_csv = "../src/data/files/processed_data_with_rolling_segments_1000C.csv"  
output_csv = "../src/data/files/bundle_data_1000_C.csv"  

def read_data_from_csv(csv_path):
    """Read product data from CSV."""
    return pd.read_csv(csv_path)

def save_bundle_to_csv(bundle, output_path):
    """Save the final bundle to a CSV file."""
    bundle_df = pd.DataFrame(bundle)
    bundle_df.to_csv(output_path, index=False)

def normalize(value, min_value, max_value):
    """Normalize the value to a common scale between 0 and 1."""
    if min_value == max_value:
        return 0
    return (value - min_value) / (max_value - min_value)

def calculate_combined_score(df, alpha, beta):
    """Calculate combined score using purchase frequency and recency."""
    min_f = df['purchase_frequency'].min()
    max_f = df['purchase_frequency'].max()
    min_r = df['recency'].min()
    max_r = df['recency'].max()
    
    df = df.copy()  # Ensure we're working with a copy
    df['normalized_f'] = df['purchase_frequency'].apply(lambda x: normalize(x, min_f, max_f))
    df['normalized_r'] = df['recency'].apply(lambda x: normalize(x, min_r, max_r))
    
    df['combined_score'] = (alpha * df['normalized_f']) + (beta * df['normalized_r'])
    return df

def select_anchor_product(df):
    """Select the anchor product based on the highest combined score."""
    return df.loc[df['combined_score'].idxmax()]

def generate_candidates(bundle, df):
    """Exclude products already in the bundle."""
    bundle_product_ids = {p['product_id'] for p in bundle}
    candidates = df[~df['product_id'].isin(bundle_product_ids)]
    return candidates

def score_candidates(candidates, bundle, gamma, delta):
    """Score candidates based on category and business rules."""
    def category_score(p):
        # Score is 1 if product's category is not in current bundle
        return 1 if p['category'] not in [b['category'] for b in bundle] else 0

    def business_score(p):
        val = random.randint(0, 3)
        print(f"Business Score Debug: product_id={p['product_id']} category={p['category']} score={val}")
        return val

    candidates = candidates.copy()
    candidates['category_score'] = candidates.apply(category_score, axis=1)
    candidates['business_score'] = candidates.apply(business_score, axis=1)
    candidates['score'] = gamma * candidates['category_score'] + delta * candidates['business_score']

    print("Candidate Categories:", candidates['category'].unique())
    print(candidates[['product_id', 'category', 'category_score', 'business_score', 'score']])
    return candidates


def build_bundle(df, anchor_product, purchasing_power, alpha, beta, k, C_max, theta, gamma, delta, n_categories):
    """
    Build a bundle that can contain up to n_categories categories.
    """
    bundle = [anchor_product]
    current_total_cost = anchor_product['price']
    categories_in_bundle = {anchor_product['category']}

    # Generate and score candidates
    candidates = generate_candidates(bundle, df)
    candidates = score_candidates(candidates, bundle, gamma, delta)

    # Filter candidates based on price constraint
    candidates = candidates[candidates['price'] <= theta * C_max]

    # Sort candidates by score in descending order for efficient selection
    candidates = candidates.sort_values(by='score', ascending=False)

    # Iterate through candidates to build the bundle
    for _, candidate in candidates.iterrows():
        if len(bundle) >= k:
            break  # Stop if bundle size is reached

        candidate_category = candidate['category']
        price = candidate['price']

        # If candidate category is new and within allowed category limit
        if candidate_category not in categories_in_bundle:
            if len(categories_in_bundle) < n_categories and current_total_cost + price <= C_max:
                bundle.append(candidate)
                current_total_cost += price
                categories_in_bundle.add(candidate_category)
        else:
            # Category already present in the bundle
            if current_total_cost + price <= C_max:
                bundle.append(candidate)
                current_total_cost += price

    # Ensure that bundles with a single product are not allowed
    if len(bundle) < 2:
        return []

    return bundle

# Read data from CSV
df = read_data_from_csv(input_csv)

bundles = []

# Iterate over each consultant
for rolling_segment, group in df.groupby('rolling_segments'):
    print(f"Generating bundles for rolling_segment {rolling_segment}")
    
    # Use the average_purchasing_power column as C_max
    rolling_segment_max = group['average_purchasing_power'].iloc[0]
    print(f"Average spending - {rolling_segment_max}")
    
    for bundle_id in range(num_bundles):  # Generate 'num_bundles' bundles for each consultant
        unique_bundle_id = f"{rolling_segment}_Bundle_{bundle_id + 1}"
        print(f"unique_bundle_id - {unique_bundle_id}")
        
        # Calculate combined score
        group_scored = calculate_combined_score(group, alpha, beta)
        
        # Select anchor product
        anchor_product = select_anchor_product(group_scored)

        # Build the bundle using average spending as C_max
        bundle = build_bundle(group_scored, anchor_product, purchasing_power, alpha, beta, k, rolling_segment_max, theta, gamma, delta, n_categories)
        
        # Skip empty bundles or bundles with a single product
        if len(bundle) < 2:
            continue

        # Calculate bundle score as the average of combined scores
        bundle_score = sum([product['combined_score'] for product in bundle]) / len(bundle)

        # Save bundle details
        for idx, product in enumerate(bundle):
            product_copy = product.copy()
            product_copy['consultant_id'] = rolling_segment
            product_copy['bundle_id'] = unique_bundle_id
            product_copy['is_anchor'] = 1 if idx == 0 else 0
            product_copy['bundle_score'] = bundle_score  # Add bundle score to each product in the bundle
            
            # Include the intermediate scores if they exist in product
            if 'category_score' in product:
                product_copy['category_score'] = product['category_score']
            if 'business_score' in product:
                product_copy['business_score'] = product['business_score']
            if 'score' in product:
                product_copy['selection_score'] = product['score']

            bundles.append(product_copy)

# Save the final bundles to CSV
save_bundle_to_csv(bundles, output_csv)
# Out:
# Generating bundles for rolling_segment Constantes 1
# Average spending - 430.195
# unique_bundle_id - Constantes 1_Bundle_1
# Business Score Debug: product_id=200093188 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200108747 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200109119 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200109163 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200102108 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200105207 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200113179 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210102044 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200103405 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210092742 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200090452 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210102013 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200106854 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200103918 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200086432 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200109874 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200090452 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200082688 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210098462 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200102045 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210097036 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200100866 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210102381 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200102648 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200109350 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200109874 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105218 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200108752 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200103733 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200089508 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200103716 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200107824 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210102010 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=210104543 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200090452 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200112474 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200101074 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200090452 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200105983 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200106304 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200102089 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210095249 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200112287 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200106573 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200107369 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200095465 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200107364 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210098496 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200103022 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200083997 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200088133 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210099080 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200094864 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200098795 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200103028 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210102338 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200090364 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=200105180 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200099203 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200112474 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=210100407 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200101589 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210102382 category=BIJOUTERIE score=3
# Business Score Debug: product_id=210099771 category=HOGAR score=1
# Business Score Debug: product_id=210102311 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200090349 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200103920 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210101275 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200106290 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200103452 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200097066 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210102045 category=RELOJES score=1
# Business Score Debug: product_id=210102044 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=200089507 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200106279 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200089987 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200094066 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200105130 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200113794 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200106459 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200064341 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200109890 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200106456 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200083913 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200100408 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200102282 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200107078 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200082687 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200092792 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200095465 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200088032 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200105011 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210101851 category=PROMOCION USUARIOS score=3
# Business Score Debug: product_id=210095994 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200107349 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210095971 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210095993 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200094162 category=MUESTRAS COSMETICOS score=2
# Business Score Debug: product_id=200110368 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210097030 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200102089 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210100496 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210102070 category=HOGAR score=3
# Business Score Debug: product_id=210104015 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200103028 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210102546 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200107429 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200114940 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200114784 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200105008 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200091727 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200114090 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200095426 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200111130 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210102020 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200094066 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200109874 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200091875 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200111352 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210100847 category=LENTES score=2
# Business Score Debug: product_id=200072913 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210097922 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210101561 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200090337 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200097947 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200103450 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200103028 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200108752 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200103964 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200111162 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200105079 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200103448 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210102116 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200060841 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=210102041 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200105008 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200103449 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200085860 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200115170 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200095382 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200101369 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200115328 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=210099425 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210102610 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200106441 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200106346 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200112530 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200106312 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200064310 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200090337 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200113792 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200094864 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200112476 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200109611 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095162 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210098462 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200113795 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200113244 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210101992 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=200104937 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200106356 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200094834 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200103027 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210101279 category=BIJOUTERIE score=1
# Business Score Debug: product_id=210100408 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200107183 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200102116 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210102316 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200102090 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200102846 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=210103814 category=VARIOS score=3
# Business Score Debug: product_id=200112306 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210099064 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200103026 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200111130 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200113208 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210097405 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200106279 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200093883 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200089508 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=200082652 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210102378 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200113735 category=VARIOS score=1
# Business Score Debug: product_id=200103026 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200086566 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200102111 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200101245 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200107143 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200106360 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200084882 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200105125 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210102071 category=HOGAR score=0
# Business Score Debug: product_id=200083902 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200097947 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200102110 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210102548 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200064341 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200095659 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200105655 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210103668 category=HOGAR score=2
# Business Score Debug: product_id=200095159 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210101369 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200106559 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200104231 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200108674 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210103668 category=HOGAR score=1
# Business Score Debug: product_id=200095177 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200112232 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200083997 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200106444 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210100409 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200105011 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210096210 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200095426 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210100660 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200110088 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200097067 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200109611 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095158 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200103405 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200104873 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210094324 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200106274 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200106397 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200095420 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200090349 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210101283 category=BIJOUTERIE score=2
# Business Score Debug: product_id=210095971 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200036215 category=ACCESORIOS COSMETICOS score=2
# Business Score Debug: product_id=200011196 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200103721 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095430 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210098324 category=ACCESORIOS COSMETICOS score=0
# Business Score Debug: product_id=200110960 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200090452 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200101406 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200085822 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200105159 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200104066 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=200095864 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210086462 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200106356 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200084882 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200102109 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200095170 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210102012 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200090452 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200108768 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200091455 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210103135 category=RELOJES score=1
# Business Score Debug: product_id=200108671 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200083976 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200113796 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200102351 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200082687 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105655 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210102039 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200113795 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200104873 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200109166 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105125 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200109162 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200106572 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210102588 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200097066 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200106444 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200064310 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200109537 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210100408 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200100926 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210101851 category=PROMOCION USUARIOS score=3
# Business Score Debug: product_id=210096236 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210102442 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210102539 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200104932 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200089508 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200109193 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200085506 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200103028 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200101225 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200086399 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200095430 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200108908 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200105005 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200093884 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200111303 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200106437 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200089168 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106463 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200102708 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200105125 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200110346 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200109352 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200102111 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200099686 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200092742 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200111302 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200082652 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210097338 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200102108 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210102545 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200097067 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200095157 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200115587 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200112361 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200109583 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200102348 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200099686 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200102370 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200088568 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200090349 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200103027 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200064341 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200109582 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200107083 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210099696 category=PROMOCION USUARIOS score=0
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200113734 category=VARIOS score=1
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210097538 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200106433 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200090352 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=210096207 category=MAQUILLAJE score=3
# Business Score Debug: product_id=400095702 category=Others score=1
# Business Score Debug: product_id=200112474 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200088133 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200098788 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200105035 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200086106 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200103733 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108584 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200102650 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200078944 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200082674 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200111234 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200082652 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210104344 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200106386 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210103623 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200107666 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200101061 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200073557 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200105079 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200087252 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200107350 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210098811 category=HOGAR score=0
# Business Score Debug: product_id=200095153 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210099671 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=400095701 category=Others score=1
# Business Score Debug: product_id=210100409 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200090365 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200102433 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200109874 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210097992 category=BIJOUTERIE score=0
# Business Score Debug: product_id=210101501 category=PROMOCION USUARIOS score=3
# Business Score Debug: product_id=210102536 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200113298 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200112352 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200113292 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200112361 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200095170 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200113891 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200105214 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200106443 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200112748 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200106312 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210105332 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200113296 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200095162 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200114986 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200090452 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105218 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200082674 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200086432 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210102606 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200095500 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200106452 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200103028 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200111391 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200089168 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200091727 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200115489 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200107850 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210105073 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200103449 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210102537 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210104899 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200105190 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200115454 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200095159 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210104906 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=210098840 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105011 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200115454 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200102433 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200115453 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200106455 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200116108 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200094832 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200091727 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200107144 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200112361 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200094941 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200114817 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200095465 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200087949 category=MUESTRAS COSMETICOS score=0
# Business Score Debug: product_id=200107369 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200095170 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200116807 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200082674 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200082674 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200099704 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200112355 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210105409 category=BIJOUTERIE score=2
# Business Score Debug: product_id=210106028 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200109338 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200109873 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200105125 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200114148 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200103449 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200097947 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200114784 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200095903 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200082974 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200102104 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200104902 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200112308 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210105402 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200114199 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200104532 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210105917 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200112307 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200113310 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095177 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200114813 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200111184 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200112290 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210105389 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200082687 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200102351 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200101110 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200113302 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210086712 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200106441 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200116798 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210103925 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200102045 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200104412 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210107061 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200114037 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200116798 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200112293 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210093923 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200111179 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200113325 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210105865 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200100926 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200100810 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200102430 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200072913 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200112748 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200094217 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106312 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210100409 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210105839 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200113887 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200109472 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200103022 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200115278 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200112748 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210093312 category=ACCESORIOS COSMETICOS score=1
# Business Score Debug: product_id=200116779 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200101369 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210105416 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200108671 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200106346 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210096207 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210105393 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=210104978 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200114550 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200115405 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200113941 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200115453 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210098308 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200106445 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200109873 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200114205 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200095158 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200107184 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200095159 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200095570 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200114192 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200094941 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210103136 category=RELOJES score=1
# Business Score Debug: product_id=200106606 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200108674 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200114191 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200112231 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108768 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200111183 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200101110 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200111379 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210106115 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200116308 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=210099094 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210100495 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200113951 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200118224 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200106396 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200108674 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210100408 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200098377 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210105401 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=200114104 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200113302 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200109613 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200090452 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106346 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210105134 category=BIJOUTERIE score=0
# Business Score Debug: product_id=210106153 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200103452 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200115663 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200114103 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200094936 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200114103 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210106165 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200111162 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210105250 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210103596 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200109610 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200113787 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200111318 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200114200 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200114207 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200086432 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200110330 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200116108 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200117052 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200095339 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200113639 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105011 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200114935 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200084882 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106360 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200114935 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200108045 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=210106607 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200102430 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210105005 category=HOGAR score=2
# Business Score Debug: product_id=210106172 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200118379 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200113548 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210104002 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200115540 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200102430 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200105985 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200116225 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210105872 category=RELOJES score=1
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200118379 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200116555 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200111162 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200111184 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200111183 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200095420 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210103498 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200116195 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200114205 category=MAQUILLAJE score=3
# ...
# Business Score Debug: product_id=200103448 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200116779 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200116781 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200116782 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200114203 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200082674 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200115496 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106852 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200112289 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200116108 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200115160 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210105416 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200116781 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200108752 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200109873 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210104989 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200091269 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200088133 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200092744 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200102108 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108908 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200110088 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200100617 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200109537 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200112355 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200090452 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200103452 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200115515 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=210102594 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200089509 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200089509 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200114983 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=200111184 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200115587 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200113293 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200117468 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210100499 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210104918 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200106560 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210101546 category=PROMOCION USUARIOS score=2
# Business Score Debug: product_id=210105394 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=210100112 category=BIJOUTERIE score=2
# Business Score Debug: product_id=210098403 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=210104526 category=HOGAR score=0
# Business Score Debug: product_id=200109566 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200100866 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200098266 category=MUESTRAS COSMETICOS score=0
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200095170 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200109537 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200105180 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200106556 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095666 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200114198 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095162 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200106604 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200115167 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200100855 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200115983 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200106556 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200115497 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210105387 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200113886 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210105862 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200112357 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200115167 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200116082 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200111132 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210105862 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200111416 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200115497 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200086399 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200113781 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200109584 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210098466 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210100408 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200116347 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=210098465 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200103020 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200095374 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200117505 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=210104365 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200111182 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=210105031 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200103450 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210098468 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115279 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200110339 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210105418 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200112352 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200105217 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200110342 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200114054 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210100409 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200110340 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210105255 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200110329 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200110337 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200091235 category=MUESTRAS COSMETICOS score=3
# Business Score Debug: product_id=200115093 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200089222 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200116780 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200110328 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210106119 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200118379 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115403 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210097089 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200111184 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200072913 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200105079 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200115976 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210097405 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200114199 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200064310 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200102045 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200114988 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200112307 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200086566 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200116782 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200118321 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200115098 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200118321 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210107682 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200113326 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200113410 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=200102045 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210106129 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=210092907 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200113410 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=210102442 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210100408 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210107062 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200106854 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200106604 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210100500 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200113881 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200117468 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210098465 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210106689 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200115796 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210107485 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200115169 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200116264 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200106360 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200103026 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200115165 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200106606 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200112361 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200103449 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210100559 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200116376 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200110342 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115551 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=210105330 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=200117564 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200082674 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200114911 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200095162 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200117577 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115403 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200095964 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105214 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200110337 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200060760 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210105156 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200106357 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200115279 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200089509 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200092906 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200101369 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200111162 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200117235 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210106628 category=RELOJES score=0
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200115587 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210105527 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200095162 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210100298 category=PROMOCION USUARIOS score=0
# Business Score Debug: product_id=200115983 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210095994 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200117468 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200114105 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108160 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210106469 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=0
# Candidate Categories: ['COMPLEMENTOS' 'CUIDADO PERSONAL' 'MAQUILLAJE' 'BIJOUTERIE' 'FRAGANCIAS'
#  'TRATAMIENTO FACIAL' 'MUESTRAS COSMETICOS' 'TRATAMIENTO CORPORAL' 'HOGAR'
#  'RELOJES' 'PROMOCION USUARIOS' 'VARIOS' 'LENTES' 'Others'
#  'ACCESORIOS COSMETICOS']
#        product_id          category  category_score  business_score  score
# 4       210100620      COMPLEMENTOS               1               0   0.25
# 5       200090349  CUIDADO PERSONAL               1               0   0.25
# 6       200082687  CUIDADO PERSONAL               1               3   2.50
# 13      200103923        MAQUILLAJE               1               0   0.25
# 14      210102316        BIJOUTERIE               0               3   2.25
# ...           ...               ...             ...             ...    ...
# 36270   200117468        MAQUILLAJE               1               2   1.75
# 36271   200114105        MAQUILLAJE               1               1   1.00
# 36273   200108160        FRAGANCIAS               1               1   1.00
# 36283   210106469        BIJOUTERIE               0               1   0.75
# 36295   200098673        FRAGANCIAS               1               0   0.25
#
# [7860 rows x 5 columns]
