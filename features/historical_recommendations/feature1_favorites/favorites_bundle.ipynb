# %%
import pandas as pd
import random

# %%
alpha = 0.5  
beta = 0.5   
purchasing_power = 100.0
k = 2  
C_max = 100.0  
theta = 1  
gamma = 0.6  
delta = 0.4  
n_categories = 2  
num_bundles = 2
input_csv = "/Users/mindstix/Documents/baseline_COP2/features/historical_recommendations/feature1_favorites/data/consultant_products.csv"  
output_csv = "/Users/mindstix/Documents/baseline_COP2/features/historical_recommendations/feature1_favorites/data/bundles.csv"

# %%
def read_data_from_csv(csv_path):
    """Read product data from CSV."""
    return pd.read_csv(csv_path)

def save_bundle_to_csv(bundle, output_path):
    """Save the final bundle to a CSV file."""
    bundle_df = pd.DataFrame(bundle)
    bundle_df.to_csv(output_path, index=False)

def normalize(value, min_value, max_value):
    """Normalize the value to a common scale between 0 and 1."""
    if min_value == max_value:
        return 0  # or 1, depending on how you want to handle this case
    return (value - min_value) / (max_value - min_value)

# %%
# This function calculates a combined score for each product based on its purchase frequency and recency, 
# with weights applied to each factor. It normalizes both values to a scale of [0, 1] to ensure comparability, 
# and then uses the weights (alpha and beta) to create the combined score.
def calculate_combined_score(df, alpha, beta):
    """Calculate combined score using purchase frequency and recency."""
    min_f = df['purchase_frequency'].min()
    max_f = df['purchase_frequency'].max()
    min_r = df['recency'].min()
    max_r = df['recency'].max()
    
    df = df.copy()  # Ensure we're working with a copy here
    df['normalized_f'] = df['purchase_frequency'].apply(lambda x: normalize(x, min_f, max_f))
    df['normalized_r'] = df['recency'].apply(lambda x: normalize(x, min_r, max_r))
    
    df['combined_score'] = (alpha * df['normalized_f']) + (beta * df['normalized_r'])
    return df

# %%
def select_anchor_product(df):
    """Select the anchor product based on the highest combined score."""
    return df.loc[df['combined_score'].idxmax()]

# %%
def generate_candidates(bundle, df, n_categories):
    """Generate candidate products related to the bundle, ensuring diversity in categories."""
    
    # Extract the product IDs and categories from the bundle
    bundle_product_ids = [p['product_id'] for p in bundle]
    # bundle_categories = set(p['category'] for p in bundle)
    
    # Find related products based on categories
    related_products = set()
    for product in bundle:
        related_products.update(df[df['category'] == product['category']]['product_id'])
    
    # Allow for products from other categories if bundle is not diverse enough
    candidates = df[~df['product_id'].isin(bundle_product_ids) & df['product_id'].isin(related_products)]
    
    # Ensure diversity: we can add products from other categories if needed
    categories_in_bundle = set(p['category'] for p in bundle)
    if len(categories_in_bundle) < n_categories:
        additional_candidates = df[~df['product_id'].isin(bundle_product_ids)]
        candidates = pd.concat([candidates, additional_candidates])
    
    return candidates

# %%
def score_candidates(candidates, bundle, gamma, delta):
    """Score candidates based on category and business rules."""
    
    # Define the category score function to promote diversity
    def category_score(p):
        # If product's category is NOT in the bundle's categories, score 1 (promote diversity)
        return 1 if p['category'] not in [b['category'] for b in bundle] else 0
    
    # Define the business score function
    def business_score(p):
        # Use some business rule or logic for scoring. Here, we use random as a placeholder.
        return random.random()  # Replace with actual business logic or scoring

    # Ensure working with a copy of the DataFrame
    candidates = candidates.copy()
    
    # Apply the scoring functions
    candidates['category_score'] = candidates.apply(category_score, axis=1)
    candidates['business_score'] = candidates.apply(business_score, axis=1)
    
    # Calculate the final score as a weighted sum
    candidates['score'] = gamma * candidates['category_score'] + delta * candidates['business_score']
    
    return candidates

# %%
def build_bundle(df, anchor_product, purchasing_power, alpha, beta, k, C_max, theta, gamma, delta, n_categories):
    """Build the bundle for a consultant while ensuring diversity in categories."""
    bundle = [anchor_product]
    current_total_cost = anchor_product['price']
    
    # Track categories in the bundle
    categories_in_bundle = {anchor_product['category']}
    
    while len(bundle) < k:  # Ensure we don't exceed the desired bundle size 'k'
        # Generate candidate products, allowing for multiple categories
        candidates = generate_candidates(bundle, df, n_categories)
        
        # Calculate combined score for the candidates
        candidates = calculate_combined_score(candidates, alpha, beta)
        candidates = score_candidates(candidates, bundle, gamma, delta)
        
        # Filter candidates based on price constraint
        candidates = candidates[candidates['price'] <= theta * C_max]
        
        if not candidates.empty:
            # Select the product with the highest score
            next_product = candidates.loc[candidates['score'].idxmax()]
            next_product = next_product if isinstance(next_product, pd.Series) else next_product.iloc[0]
            price = next_product['price']
            
            # Check if adding this product respects the purchasing power and total cost
            if current_total_cost + price <= C_max:
                bundle.append(next_product)
                current_total_cost += price
                categories_in_bundle.add(next_product['category'])
        else:
            # Exit if no valid candidates are available
            break
    
    return bundle

# %%
# Read data from CSV
df = read_data_from_csv(input_csv)

# %%
bundles = []

# %%
# Iterate over each consultant
for consultant_id, group in df.groupby('consultant_id'):
    print(f"Generating bundles for Consultant {consultant_id}")
    
    for bundle_id in range(num_bundles):  # Generate 'num_bundles' bundles for each consultant
        unique_bundle_id = f"{consultant_id}_Bundle_{bundle_id + 1}"
        print(f"unique_bundle_id - {unique_bundle_id}")
        
        # Calculate combined score for each product in this group
        group = calculate_combined_score(group, alpha, beta)
        print(f"group - {group}")
        
        # Select the anchor product for the consultant
        anchor_product = select_anchor_product(group)
        print(f"anchor_product - {anchor_product}")
        
        # Build the bundle for the consultant
        bundle = build_bundle(group, anchor_product, purchasing_power, alpha, beta, k, C_max, theta, gamma, delta, n_categories)
        print(f"bundle - {bundle}")
        
        for idx, product in enumerate(bundle):
            product_copy = product.copy()  # Ensure that we are working with a copy
            product_copy['consultant_id'] = consultant_id
            product_copy['bundle_id'] = unique_bundle_id  # Add the unique bundle_id to the product
            
            # Mark the anchor product as 1, others as 0
            product_copy['is_anchor'] = 1 if idx == 0 else 0
            
            bundles.append(product_copy)
# Out:
# Generating bundles for Consultant C123
# unique_bundle_id - C123_Bundle_1
# group -   consultant_id product_id        product_name  category   brand  price  \
# 0          C123       P001  Moisturizing Cream  Skincare  BrandA   25.0
# 1          C123       P002     Vitamin C Serum  Skincare  BrandB   30.0
# 2          C123       P003      Matte Lipstick    Makeup  BrandC   15.0
# 3          C123       P004  Night Repair Cream  Skincare  BrandA   40.0
# 4          C123       P005  Eye Shadow Palette    Makeup  BrandD   20.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 0   Size: 200ml                   5        2          1.00          0.25
# 1    Size: 50ml                   3        1          0.50          0.00
# 2    Shade: Red                   2        5          0.25          1.00
# 3   Size: 100ml                   4        3          0.75          0.50
# 4  Shade: Multi                   1        4          0.00          0.75
#
#    combined_score
# 0           0.625
# 1           0.250
# 2           0.625
# 3           0.625
# 4           0.375
# anchor_product - consultant_id                       C123
# product_id                          P001
# product_name          Moisturizing Cream
# category                        Skincare
# brand                             BrandA
# price                               25.0
# attributes                   Size: 200ml
# purchase_frequency                     5
# recency                                2
# normalized_f                         1.0
# normalized_r                        0.25
# combined_score                     0.625
# Name: 0, dtype: object
# bundle - [consultant_id                       C123
# product_id                          P001
# product_name          Moisturizing Cream
# category                        Skincare
# brand                             BrandA
# price                               25.0
# attributes                   Size: 200ml
# purchase_frequency                     5
# recency                                2
# normalized_f                         1.0
# normalized_r                        0.25
# combined_score                     0.625
# Name: 0, dtype: object, consultant_id                       C123
# product_id                          P005
# product_name          Eye Shadow Palette
# category                          Makeup
# brand                             BrandD
# price                               20.0
# attributes                  Shade: Multi
# purchase_frequency                     1
# recency                                4
# normalized_f                         0.0
# normalized_r                        0.75
# combined_score                     0.375
# category_score                         1
# business_score                  0.833318
# score                           0.933327
# Name: 4, dtype: object]
# unique_bundle_id - C123_Bundle_2
# group -   consultant_id product_id        product_name  category   brand  price  \
# 0          C123       P001  Moisturizing Cream  Skincare  BrandA   25.0
# 1          C123       P002     Vitamin C Serum  Skincare  BrandB   30.0
# 2          C123       P003      Matte Lipstick    Makeup  BrandC   15.0
# 3          C123       P004  Night Repair Cream  Skincare  BrandA   40.0
# 4          C123       P005  Eye Shadow Palette    Makeup  BrandD   20.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 0   Size: 200ml                   5        2          1.00          0.25
# 1    Size: 50ml                   3        1          0.50          0.00
# 2    Shade: Red                   2        5          0.25          1.00
# 3   Size: 100ml                   4        3          0.75          0.50
# 4  Shade: Multi                   1        4          0.00          0.75
#
#    combined_score
# 0           0.625
# 1           0.250
# 2           0.625
# 3           0.625
# 4           0.375
# anchor_product - consultant_id                       C123
# product_id                          P001
# product_name          Moisturizing Cream
# category                        Skincare
# brand                             BrandA
# price                               25.0
# attributes                   Size: 200ml
# purchase_frequency                     5
# recency                                2
# normalized_f                         1.0
# normalized_r                        0.25
# combined_score                     0.625
# Name: 0, dtype: object
# bundle - [consultant_id                       C123
# product_id                          P001
# product_name          Moisturizing Cream
# category                        Skincare
# brand                             BrandA
# price                               25.0
# attributes                   Size: 200ml
# purchase_frequency                     5
# recency                                2
# normalized_f                         1.0
# normalized_r                        0.25
# combined_score                     0.625
# Name: 0, dtype: object, consultant_id                       C123
# product_id                          P005
# product_name          Eye Shadow Palette
# category                          Makeup
# brand                             BrandD
# price                               20.0
# attributes                  Shade: Multi
# purchase_frequency                     1
# recency                                4
# normalized_f                         0.0
# normalized_r                        0.75
# combined_score                     0.375
# category_score                         1
# business_score                  0.632937
# score                           0.853175
# Name: 4, dtype: object]
# Generating bundles for Consultant C124
# unique_bundle_id - C124_Bundle_1
# group -   consultant_id product_id product_name  category   brand  price  \
# 5          C124       P006      Shampoo  Skincare  BrandE   10.0
# 6          C124       P007  Conditioner  Skincare  BrandF   12.0
# 7          C124       P008     Lip Balm    Makeup  BrandG    8.0
# 8          C124       P009     BB Cream    Makeup  BrandH   18.0
# 9          C124       P010    Face Wash  Skincare  BrandE   15.0
#
#       attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 5    Size: 300ml                   7        1           0.4      0.000000
# 6    Size: 300ml                   6        2           0.2      0.333333
# 7   Flavor: Mint                  10        4           1.0      1.000000
# 8  Shade: Medium                   5        3           0.0      0.666667
# 9    Size: 200ml                   8        2           0.6      0.333333
#
#    combined_score
# 5        0.200000
# 6        0.266667
# 7        1.000000
# 8        0.333333
# 9        0.466667
# anchor_product - consultant_id                 C124
# product_id                    P008
# product_name              Lip Balm
# category                    Makeup
# brand                       BrandG
# price                          8.0
# attributes            Flavor: Mint
# purchase_frequency              10
# recency                          4
# normalized_f                   1.0
# normalized_r                   1.0
# combined_score                 1.0
# Name: 7, dtype: object
# bundle - [consultant_id                 C124
# product_id                    P008
# product_name              Lip Balm
# category                    Makeup
# brand                       BrandG
# price                          8.0
# attributes            Flavor: Mint
# purchase_frequency              10
# recency                          4
# normalized_f                   1.0
# normalized_r                   1.0
# combined_score                 1.0
# Name: 7, dtype: object, consultant_id                C124
# product_id                   P010
# product_name            Face Wash
# category                 Skincare
# brand                      BrandE
# price                        15.0
# attributes            Size: 200ml
# purchase_frequency              8
# recency                         2
# normalized_f                  1.0
# normalized_r                  0.5
# combined_score               0.75
# category_score                  1
# business_score           0.821712
# score                    0.928685
# Name: 9, dtype: object]
# unique_bundle_id - C124_Bundle_2
# group -   consultant_id product_id product_name  category   brand  price  \
# 5          C124       P006      Shampoo  Skincare  BrandE   10.0
# 6          C124       P007  Conditioner  Skincare  BrandF   12.0
# 7          C124       P008     Lip Balm    Makeup  BrandG    8.0
# 8          C124       P009     BB Cream    Makeup  BrandH   18.0
# 9          C124       P010    Face Wash  Skincare  BrandE   15.0
#
#       attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 5    Size: 300ml                   7        1           0.4      0.000000
# 6    Size: 300ml                   6        2           0.2      0.333333
# 7   Flavor: Mint                  10        4           1.0      1.000000
# 8  Shade: Medium                   5        3           0.0      0.666667
# 9    Size: 200ml                   8        2           0.6      0.333333
#
#    combined_score
# 5        0.200000
# 6        0.266667
# 7        1.000000
# 8        0.333333
# 9        0.466667
# anchor_product - consultant_id                 C124
# product_id                    P008
# product_name              Lip Balm
# category                    Makeup
# brand                       BrandG
# price                          8.0
# attributes            Flavor: Mint
# purchase_frequency              10
# recency                          4
# normalized_f                   1.0
# normalized_r                   1.0
# combined_score                 1.0
# Name: 7, dtype: object
# bundle - [consultant_id                 C124
# product_id                    P008
# product_name              Lip Balm
# category                    Makeup
# brand                       BrandG
# price                          8.0
# attributes            Flavor: Mint
# purchase_frequency              10
# recency                          4
# normalized_f                   1.0
# normalized_r                   1.0
# combined_score                 1.0
# Name: 7, dtype: object, consultant_id                C124
# product_id                   P010
# product_name            Face Wash
# category                 Skincare
# brand                      BrandE
# price                        15.0
# attributes            Size: 200ml
# purchase_frequency              8
# recency                         2
# normalized_f                  1.0
# normalized_r                  0.5
# combined_score               0.75
# category_score                  1
# business_score           0.801754
# score                    0.920702
# Name: 9, dtype: object]
# Generating bundles for Consultant C125
# unique_bundle_id - C125_Bundle_1
# group -    consultant_id product_id product_name  category   brand  price  \
# 10          C125       P011   Hand Cream  Skincare  BrandI   22.0
# 11          C125       P012      Perfume    Beauty  BrandJ   50.0
# 12          C125       P013  Nail Polish    Makeup  BrandK   10.0
# 13          C125       P014   Face Scrub  Skincare  BrandL   20.0
# 14          C125       P015    Lip Gloss    Makeup  BrandM   12.0
#
#        attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 10    Size: 150ml                   4        5      0.166667          1.00
# 11  Scent: Floral                   3        1      0.000000          0.00
# 12    Color: Pink                   6        2      0.500000          0.25
# 13    Size: 100ml                   7        3      0.666667          0.50
# 14    Shade: Nude                   9        4      1.000000          0.75
#
#     combined_score
# 10        0.583333
# 11        0.000000
# 12        0.375000
# 13        0.583333
# 14        0.875000
# anchor_product - consultant_id                C125
# product_id                   P015
# product_name            Lip Gloss
# category                   Makeup
# brand                      BrandM
# price                        12.0
# attributes            Shade: Nude
# purchase_frequency              9
# recency                         4
# normalized_f                  1.0
# normalized_r                 0.75
# combined_score              0.875
# Name: 14, dtype: object
# bundle - [consultant_id                C125
# product_id                   P015
# product_name            Lip Gloss
# category                   Makeup
# brand                      BrandM
# price                        12.0
# attributes            Shade: Nude
# purchase_frequency              9
# recency                         4
# normalized_f                  1.0
# normalized_r                 0.75
# combined_score              0.875
# Name: 14, dtype: object, consultant_id                  C125
# product_id                     P012
# product_name                Perfume
# category                     Beauty
# brand                        BrandJ
# price                          50.0
# attributes            Scent: Floral
# purchase_frequency                3
# recency                           1
# normalized_f                    0.0
# normalized_r                    0.0
# combined_score                  0.0
# category_score                    1
# business_score             0.649957
# score                      0.859983
# Name: 11, dtype: object]
# unique_bundle_id - C125_Bundle_2
# group -    consultant_id product_id product_name  category   brand  price  \
# 10          C125       P011   Hand Cream  Skincare  BrandI   22.0
# 11          C125       P012      Perfume    Beauty  BrandJ   50.0
# 12          C125       P013  Nail Polish    Makeup  BrandK   10.0
# 13          C125       P014   Face Scrub  Skincare  BrandL   20.0
# 14          C125       P015    Lip Gloss    Makeup  BrandM   12.0
#
#        attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 10    Size: 150ml                   4        5      0.166667          1.00
# 11  Scent: Floral                   3        1      0.000000          0.00
# 12    Color: Pink                   6        2      0.500000          0.25
# 13    Size: 100ml                   7        3      0.666667          0.50
# 14    Shade: Nude                   9        4      1.000000          0.75
#
#     combined_score
# 10        0.583333
# 11        0.000000
# 12        0.375000
# 13        0.583333
# 14        0.875000
# anchor_product - consultant_id                C125
# product_id                   P015
# product_name            Lip Gloss
# category                   Makeup
# brand                      BrandM
# price                        12.0
# attributes            Shade: Nude
# purchase_frequency              9
# recency                         4
# normalized_f                  1.0
# normalized_r                 0.75
# combined_score              0.875
# Name: 14, dtype: object
# bundle - [consultant_id                C125
# product_id                   P015
# product_name            Lip Gloss
# category                   Makeup
# brand                      BrandM
# price                        12.0
# attributes            Shade: Nude
# purchase_frequency              9
# recency                         4
# normalized_f                  1.0
# normalized_r                 0.75
# combined_score              0.875
# Name: 14, dtype: object, consultant_id                  C125
# product_id                     P012
# product_name                Perfume
# category                     Beauty
# brand                        BrandJ
# price                          50.0
# attributes            Scent: Floral
# purchase_frequency                3
# recency                           1
# normalized_f                    0.0
# normalized_r                    0.0
# combined_score                  0.0
# category_score                    1
# business_score             0.846377
# score                      0.938551
# Name: 11, dtype: object]
# Generating bundles for Consultant C126
# unique_bundle_id - C126_Bundle_1
# group -    consultant_id product_id      product_name    category   brand  price  \
# 15          C126       P016     Shaving Cream  Men's Care  BrandN    8.0
# 16          C126       P017  After Shave Balm  Men's Care  BrandO   15.0
# 17          C126       P018          Hair Gel  Men's Care  BrandP   12.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 15  Size: 150ml                  10        2           1.0           0.5
# 16  Size: 100ml                   6        1           0.0           0.0
# 17  Size: 200ml                   8        3           0.5           1.0
#
#     combined_score
# 15            0.75
# 16            0.00
# 17            0.75
# anchor_product - consultant_id                  C126
# product_id                     P016
# product_name          Shaving Cream
# category                 Men's Care
# brand                        BrandN
# price                           8.0
# attributes              Size: 150ml
# purchase_frequency               10
# recency                           2
# normalized_f                    1.0
# normalized_r                    0.5
# combined_score                 0.75
# Name: 15, dtype: object
# bundle - [consultant_id                  C126
# product_id                     P016
# product_name          Shaving Cream
# category                 Men's Care
# brand                        BrandN
# price                           8.0
# attributes              Size: 150ml
# purchase_frequency               10
# recency                           2
# normalized_f                    1.0
# normalized_r                    0.5
# combined_score                 0.75
# Name: 15, dtype: object, consultant_id                     C126
# product_id                        P017
# product_name          After Shave Balm
# category                    Men's Care
# brand                           BrandO
# price                             15.0
# attributes                 Size: 100ml
# purchase_frequency                   6
# recency                              1
# normalized_f                       0.0
# normalized_r                       0.0
# combined_score                     0.0
# category_score                       0
# business_score                0.144745
# score                         0.057898
# Name: 16, dtype: object]
# unique_bundle_id - C126_Bundle_2
# group -    consultant_id product_id      product_name    category   brand  price  \
# 15          C126       P016     Shaving Cream  Men's Care  BrandN    8.0
# 16          C126       P017  After Shave Balm  Men's Care  BrandO   15.0
# 17          C126       P018          Hair Gel  Men's Care  BrandP   12.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 15  Size: 150ml                  10        2           1.0           0.5
# 16  Size: 100ml                   6        1           0.0           0.0
# 17  Size: 200ml                   8        3           0.5           1.0
#
#     combined_score
# 15            0.75
# 16            0.00
# 17            0.75
# anchor_product - consultant_id                  C126
# product_id                     P016
# product_name          Shaving Cream
# category                 Men's Care
# brand                        BrandN
# price                           8.0
# attributes              Size: 150ml
# purchase_frequency               10
# recency                           2
# normalized_f                    1.0
# normalized_r                    0.5
# combined_score                 0.75
# Name: 15, dtype: object
# bundle - [consultant_id                  C126
# product_id                     P016
# product_name          Shaving Cream
# category                 Men's Care
# brand                        BrandN
# price                           8.0
# attributes              Size: 150ml
# purchase_frequency               10
# recency                           2
# normalized_f                    1.0
# normalized_r                    0.5
# combined_score                 0.75
# Name: 15, dtype: object, consultant_id                     C126
# product_id                        P017
# product_name          After Shave Balm
# category                    Men's Care
# brand                           BrandO
# price                             15.0
# attributes                 Size: 100ml
# purchase_frequency                   6
# recency                              1
# normalized_f                       0.0
# normalized_r                       0.0
# combined_score                     0.0
# category_score                       0
# business_score                0.997647
# score                         0.399059
# Name: 16, dtype: object]
# Generating bundles for Consultant C127
# unique_bundle_id - C127_Bundle_1
# group -    consultant_id product_id product_name  category   brand  price  \
# 18          C127       P019  Body Lotion  Skincare  BrandQ   18.0
# 19          C127       P020    Sunscreen  Skincare  BrandR   20.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 18  Size: 250ml                   7        5           1.0           1.0
# 19      SPF: 50                   5        4           0.0           0.0
#
#     combined_score
# 18             1.0
# 19             0.0
# anchor_product - consultant_id                C127
# product_id                   P019
# product_name          Body Lotion
# category                 Skincare
# brand                      BrandQ
# price                        18.0
# attributes            Size: 250ml
# purchase_frequency              7
# recency                         5
# normalized_f                  1.0
# normalized_r                  1.0
# combined_score                1.0
# Name: 18, dtype: object
# bundle - [consultant_id                C127
# product_id                   P019
# product_name          Body Lotion
# category                 Skincare
# brand                      BrandQ
# price                        18.0
# attributes            Size: 250ml
# purchase_frequency              7
# recency                         5
# normalized_f                  1.0
# normalized_r                  1.0
# combined_score                1.0
# Name: 18, dtype: object, consultant_id              C127
# product_id                 P020
# product_name          Sunscreen
# category               Skincare
# brand                    BrandR
# price                      20.0
# attributes              SPF: 50
# purchase_frequency            5
# recency                       4
# normalized_f                  0
# normalized_r                  0
# combined_score              0.0
# category_score                0
# business_score         0.361933
# score                  0.144773
# Name: 19, dtype: object]
# unique_bundle_id - C127_Bundle_2
# group -    consultant_id product_id product_name  category   brand  price  \
# 18          C127       P019  Body Lotion  Skincare  BrandQ   18.0
# 19          C127       P020    Sunscreen  Skincare  BrandR   20.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 18  Size: 250ml                   7        5           1.0           1.0
# 19      SPF: 50                   5        4           0.0           0.0
#
#     combined_score
# 18             1.0
# 19             0.0
# anchor_product - consultant_id                C127
# product_id                   P019
# product_name          Body Lotion
# category                 Skincare
# brand                      BrandQ
# price                        18.0
# attributes            Size: 250ml
# purchase_frequency              7
# recency                         5
# normalized_f                  1.0
# normalized_r                  1.0
# combined_score                1.0
# Name: 18, dtype: object
# bundle - [consultant_id                C127
# product_id                   P019
# product_name          Body Lotion
# category                 Skincare
# brand                      BrandQ
# price                        18.0
# attributes            Size: 250ml
# purchase_frequency              7
# recency                         5
# normalized_f                  1.0
# normalized_r                  1.0
# combined_score                1.0
# Name: 18, dtype: object, consultant_id              C127
# product_id                 P020
# product_name          Sunscreen
# category               Skincare
# brand                    BrandR
# price                      20.0
# attributes              SPF: 50
# purchase_frequency            5
# recency                       4
# normalized_f                  0
# normalized_r                  0
# combined_score              0.0
# category_score                0
# business_score         0.210038
# score                  0.084015
# Name: 19, dtype: object]
# Generating bundles for Consultant C128
# unique_bundle_id - C128_Bundle_1
# group -    consultant_id product_id      product_name  category   brand  price  \
# 20          C128       P021   Hydrating Toner  Skincare  BrandS   18.0
# 21          C128       P022  Anti-Aging Serum  Skincare  BrandT   45.0
# 22          C128       P023   Liquid Eyeliner    Makeup  BrandU   14.0
#
#       attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 20   Size: 150ml                   4        3          0.25           1.0
# 21    Size: 50ml                   3        2          0.00           0.5
# 22  Shade: Black                   7        1          1.00           0.0
#
#     combined_score
# 20           0.625
# 21           0.250
# 22           0.500
# anchor_product - consultant_id                    C128
# product_id                       P021
# product_name          Hydrating Toner
# category                     Skincare
# brand                          BrandS
# price                            18.0
# attributes                Size: 150ml
# purchase_frequency                  4
# recency                             3
# normalized_f                     0.25
# normalized_r                      1.0
# combined_score                  0.625
# Name: 20, dtype: object
# bundle - [consultant_id                    C128
# product_id                       P021
# product_name          Hydrating Toner
# category                     Skincare
# brand                          BrandS
# price                            18.0
# attributes                Size: 150ml
# purchase_frequency                  4
# recency                             3
# normalized_f                     0.25
# normalized_r                      1.0
# combined_score                  0.625
# Name: 20, dtype: object, consultant_id                    C128
# product_id                       P023
# product_name          Liquid Eyeliner
# category                       Makeup
# brand                          BrandU
# price                            14.0
# attributes               Shade: Black
# purchase_frequency                  7
# recency                             1
# normalized_f                      1.0
# normalized_r                      0.0
# combined_score                    0.5
# category_score                      1
# business_score               0.048805
# score                        0.619522
# Name: 22, dtype: object]
# unique_bundle_id - C128_Bundle_2
# group -    consultant_id product_id      product_name  category   brand  price  \
# 20          C128       P021   Hydrating Toner  Skincare  BrandS   18.0
# 21          C128       P022  Anti-Aging Serum  Skincare  BrandT   45.0
# 22          C128       P023   Liquid Eyeliner    Makeup  BrandU   14.0
#
#       attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 20   Size: 150ml                   4        3          0.25           1.0
# 21    Size: 50ml                   3        2          0.00           0.5
# 22  Shade: Black                   7        1          1.00           0.0
#
#     combined_score
# 20           0.625
# 21           0.250
# 22           0.500
# anchor_product - consultant_id                    C128
# product_id                       P021
# product_name          Hydrating Toner
# category                     Skincare
# brand                          BrandS
# price                            18.0
# attributes                Size: 150ml
# purchase_frequency                  4
# recency                             3
# normalized_f                     0.25
# normalized_r                      1.0
# combined_score                  0.625
# Name: 20, dtype: object
# bundle - [consultant_id                    C128
# product_id                       P021
# product_name          Hydrating Toner
# category                     Skincare
# brand                          BrandS
# price                            18.0
# attributes                Size: 150ml
# purchase_frequency                  4
# recency                             3
# normalized_f                     0.25
# normalized_r                      1.0
# combined_score                  0.625
# Name: 20, dtype: object, consultant_id                    C128
# product_id                       P023
# product_name          Liquid Eyeliner
# category                       Makeup
# brand                          BrandU
# price                            14.0
# attributes               Shade: Black
# purchase_frequency                  7
# recency                             1
# normalized_f                      1.0
# normalized_r                      0.0
# combined_score                    0.5
# category_score                      1
# business_score               0.141442
# score                        0.656577
# Name: 22, dtype: object]
# Generating bundles for Consultant C129
# unique_bundle_id - C129_Bundle_1
# group -    consultant_id product_id product_name    category   brand  price  \
# 23          C129       P024    Beard Oil  Men's Care  BrandV   20.0
# 24          C129       P025     Hair Wax  Men's Care  BrandW   15.0
# 25          C129       P026    Face Mist    Skincare  BrandX   12.0
# 26          C129       P027   Foot Cream   Body Care  BrandY   16.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 23  Size: 100ml                   5        4           0.2      0.666667
# 24   Size: 75ml                   8        2           0.8      0.000000
# 25  Size: 100ml                   9        3           1.0      0.333333
# 26  Size: 120ml                   4        5           0.0      1.000000
#
#     combined_score
# 23        0.433333
# 24        0.400000
# 25        0.666667
# 26        0.500000
# anchor_product - consultant_id                C129
# product_id                   P026
# product_name            Face Mist
# category                 Skincare
# brand                      BrandX
# price                        12.0
# attributes            Size: 100ml
# purchase_frequency              9
# recency                         3
# normalized_f                  1.0
# normalized_r             0.333333
# combined_score           0.666667
# Name: 25, dtype: object
# bundle - [consultant_id                C129
# product_id                   P026
# product_name            Face Mist
# category                 Skincare
# brand                      BrandX
# price                        12.0
# attributes            Size: 100ml
# purchase_frequency              9
# recency                         3
# normalized_f                  1.0
# normalized_r             0.333333
# combined_score           0.666667
# Name: 25, dtype: object, consultant_id               C129
# product_id                  P025
# product_name            Hair Wax
# category              Men's Care
# brand                     BrandW
# price                       15.0
# attributes            Size: 75ml
# purchase_frequency             8
# recency                        2
# normalized_f                 1.0
# normalized_r                 0.0
# combined_score               0.5
# category_score                 1
# business_score          0.757931
# score                   0.903172
# Name: 24, dtype: object]
# unique_bundle_id - C129_Bundle_2
# group -    consultant_id product_id product_name    category   brand  price  \
# 23          C129       P024    Beard Oil  Men's Care  BrandV   20.0
# 24          C129       P025     Hair Wax  Men's Care  BrandW   15.0
# 25          C129       P026    Face Mist    Skincare  BrandX   12.0
# 26          C129       P027   Foot Cream   Body Care  BrandY   16.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 23  Size: 100ml                   5        4           0.2      0.666667
# 24   Size: 75ml                   8        2           0.8      0.000000
# 25  Size: 100ml                   9        3           1.0      0.333333
# 26  Size: 120ml                   4        5           0.0      1.000000
#
#     combined_score
# 23        0.433333
# 24        0.400000
# 25        0.666667
# 26        0.500000
# anchor_product - consultant_id                C129
# product_id                   P026
# product_name            Face Mist
# category                 Skincare
# brand                      BrandX
# price                        12.0
# attributes            Size: 100ml
# purchase_frequency              9
# recency                         3
# normalized_f                  1.0
# normalized_r             0.333333
# combined_score           0.666667
# Name: 25, dtype: object
# bundle - [consultant_id                C129
# product_id                   P026
# product_name            Face Mist
# category                 Skincare
# brand                      BrandX
# price                        12.0
# attributes            Size: 100ml
# purchase_frequency              9
# recency                         3
# normalized_f                  1.0
# normalized_r             0.333333
# combined_score           0.666667
# Name: 25, dtype: object, consultant_id               C129
# product_id                  P025
# product_name            Hair Wax
# category              Men's Care
# brand                     BrandW
# price                       15.0
# attributes            Size: 75ml
# purchase_frequency             8
# recency                        2
# normalized_f                 1.0
# normalized_r                 0.0
# combined_score               0.5
# category_score                 1
# business_score          0.271106
# score                   0.708443
# Name: 24, dtype: object]
# Generating bundles for Consultant C130
# unique_bundle_id - C130_Bundle_1
# group -    consultant_id product_id      product_name   category    brand  price  \
# 27          C130       P028    Compact Powder     Makeup   BrandZ   22.0
# 28          C130       P029       Massage Oil  Body Care  BrandA1   25.0
# 29          C130       P030  Hair Conditioner  Hair Care  BrandB1   14.0
#
#       attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 27  Shade: Beige                   6        2          0.75           0.5
# 28   Size: 250ml                   3        1          0.00           0.0
# 29   Size: 500ml                   7        3          1.00           1.0
#
#     combined_score
# 27           0.625
# 28           0.000
# 29           1.000
# anchor_product - consultant_id                     C130
# product_id                        P030
# product_name          Hair Conditioner
# category                     Hair Care
# brand                          BrandB1
# price                             14.0
# attributes                 Size: 500ml
# purchase_frequency                   7
# recency                              3
# normalized_f                       1.0
# normalized_r                       1.0
# combined_score                     1.0
# Name: 29, dtype: object
# bundle - [consultant_id                     C130
# product_id                        P030
# product_name          Hair Conditioner
# category                     Hair Care
# brand                          BrandB1
# price                             14.0
# attributes                 Size: 500ml
# purchase_frequency                   7
# recency                              3
# normalized_f                       1.0
# normalized_r                       1.0
# combined_score                     1.0
# Name: 29, dtype: object, consultant_id                C130
# product_id                   P029
# product_name          Massage Oil
# category                Body Care
# brand                     BrandA1
# price                        25.0
# attributes            Size: 250ml
# purchase_frequency              3
# recency                         1
# normalized_f                  0.0
# normalized_r                  0.0
# combined_score                0.0
# category_score                  1
# business_score           0.974194
# score                    0.989678
# Name: 28, dtype: object]
# unique_bundle_id - C130_Bundle_2
# group -    consultant_id product_id      product_name   category    brand  price  \
# 27          C130       P028    Compact Powder     Makeup   BrandZ   22.0
# 28          C130       P029       Massage Oil  Body Care  BrandA1   25.0
# 29          C130       P030  Hair Conditioner  Hair Care  BrandB1   14.0
#
#       attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 27  Shade: Beige                   6        2          0.75           0.5
# 28   Size: 250ml                   3        1          0.00           0.0
# 29   Size: 500ml                   7        3          1.00           1.0
#
#     combined_score
# 27           0.625
# 28           0.000
# 29           1.000
# anchor_product - consultant_id                     C130
# product_id                        P030
# product_name          Hair Conditioner
# category                     Hair Care
# brand                          BrandB1
# price                             14.0
# attributes                 Size: 500ml
# purchase_frequency                   7
# recency                              3
# normalized_f                       1.0
# normalized_r                       1.0
# combined_score                     1.0
# Name: 29, dtype: object
# bundle - [consultant_id                     C130
# product_id                        P030
# product_name          Hair Conditioner
# category                     Hair Care
# brand                          BrandB1
# price                             14.0
# attributes                 Size: 500ml
# purchase_frequency                   7
# recency                              3
# normalized_f                       1.0
# normalized_r                       1.0
# combined_score                     1.0
# Name: 29, dtype: object, consultant_id                C130
# product_id                   P029
# product_name          Massage Oil
# category                Body Care
# brand                     BrandA1
# price                        25.0
# attributes            Size: 250ml
# purchase_frequency              3
# recency                         1
# normalized_f                  0.0
# normalized_r                  0.0
# combined_score                0.0
# category_score                  1
# business_score           0.499822
# score                    0.799929
# Name: 28, dtype: object]
# Generating bundles for Consultant C131
# unique_bundle_id - C131_Bundle_1
# group -    consultant_id product_id     product_name   category    brand  price  \
# 30          C131       P031       Shower Gel  Body Care  BrandC1   10.0
# 31          C131       P032  Eau De Toilette     Beauty  BrandD1   55.0
# 32          C131       P033    Blush Palette     Makeup  BrandE1   28.0
#
#        attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 30    Size: 300ml                  10        4          1.00           0.5
# 31  Scent: Citrus                   2        5          0.00           1.0
# 32    Shade: Rose                   4        3          0.25           0.0
#
#     combined_score
# 30           0.750
# 31           0.500
# 32           0.125
# anchor_product - consultant_id                C131
# product_id                   P031
# product_name           Shower Gel
# category                Body Care
# brand                     BrandC1
# price                        10.0
# attributes            Size: 300ml
# purchase_frequency             10
# recency                         4
# normalized_f                  1.0
# normalized_r                  0.5
# combined_score               0.75
# Name: 30, dtype: object
# bundle - [consultant_id                C131
# product_id                   P031
# product_name           Shower Gel
# category                Body Care
# brand                     BrandC1
# price                        10.0
# attributes            Size: 300ml
# purchase_frequency             10
# recency                         4
# normalized_f                  1.0
# normalized_r                  0.5
# combined_score               0.75
# Name: 30, dtype: object, consultant_id                  C131
# product_id                     P033
# product_name          Blush Palette
# category                     Makeup
# brand                       BrandE1
# price                          28.0
# attributes              Shade: Rose
# purchase_frequency                4
# recency                           3
# normalized_f                    1.0
# normalized_r                    0.0
# combined_score                  0.5
# category_score                    1
# business_score             0.576843
# score                      0.830737
# Name: 32, dtype: object]
# unique_bundle_id - C131_Bundle_2
# group -    consultant_id product_id     product_name   category    brand  price  \
# 30          C131       P031       Shower Gel  Body Care  BrandC1   10.0
# 31          C131       P032  Eau De Toilette     Beauty  BrandD1   55.0
# 32          C131       P033    Blush Palette     Makeup  BrandE1   28.0
#
#        attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 30    Size: 300ml                  10        4          1.00           0.5
# 31  Scent: Citrus                   2        5          0.00           1.0
# 32    Shade: Rose                   4        3          0.25           0.0
#
#     combined_score
# 30           0.750
# 31           0.500
# 32           0.125
# anchor_product - consultant_id                C131
# product_id                   P031
# product_name           Shower Gel
# category                Body Care
# brand                     BrandC1
# price                        10.0
# attributes            Size: 300ml
# purchase_frequency             10
# recency                         4
# normalized_f                  1.0
# normalized_r                  0.5
# combined_score               0.75
# Name: 30, dtype: object
# bundle - [consultant_id                C131
# product_id                   P031
# product_name           Shower Gel
# category                Body Care
# brand                     BrandC1
# price                        10.0
# attributes            Size: 300ml
# purchase_frequency             10
# recency                         4
# normalized_f                  1.0
# normalized_r                  0.5
# combined_score               0.75
# Name: 30, dtype: object, consultant_id                    C131
# product_id                       P032
# product_name          Eau De Toilette
# category                       Beauty
# brand                         BrandD1
# price                            55.0
# attributes              Scent: Citrus
# purchase_frequency                  2
# recency                             5
# normalized_f                      0.0
# normalized_r                      1.0
# combined_score                    0.5
# category_score                      1
# business_score               0.843659
# score                        0.937464
# Name: 31, dtype: object]
# Generating bundles for Consultant C132
# unique_bundle_id - C132_Bundle_1
# group -    consultant_id product_id     product_name    category    brand  price  \
# 33          C132       P034  Deodorant Stick  Men's Care  BrandF1    9.0
# 34          C132       P035       Hair Serum   Hair Care  BrandG1   18.0
# 35          C132       P036      Body Butter   Body Care  BrandH1   20.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 33    Size: 75g                   6        2      0.333333      0.333333
# 34  Size: 100ml                   8        1      1.000000      0.000000
# 35  Size: 200ml                   5        4      0.000000      1.000000
#
#     combined_score
# 33        0.333333
# 34        0.500000
# 35        0.500000
# anchor_product - consultant_id                C132
# product_id                   P035
# product_name           Hair Serum
# category                Hair Care
# brand                     BrandG1
# price                        18.0
# attributes            Size: 100ml
# purchase_frequency              8
# recency                         1
# normalized_f                  1.0
# normalized_r                  0.0
# combined_score                0.5
# Name: 34, dtype: object
# bundle - [consultant_id                C132
# product_id                   P035
# product_name           Hair Serum
# category                Hair Care
# brand                     BrandG1
# price                        18.0
# attributes            Size: 100ml
# purchase_frequency              8
# recency                         1
# normalized_f                  1.0
# normalized_r                  0.0
# combined_score                0.5
# Name: 34, dtype: object, consultant_id                    C132
# product_id                       P034
# product_name          Deodorant Stick
# category                   Men's Care
# brand                         BrandF1
# price                             9.0
# attributes                  Size: 75g
# purchase_frequency                  6
# recency                             2
# normalized_f                      1.0
# normalized_r                      0.0
# combined_score                    0.5
# category_score                      1
# business_score               0.441716
# score                        0.776686
# Name: 33, dtype: object]
# unique_bundle_id - C132_Bundle_2
# group -    consultant_id product_id     product_name    category    brand  price  \
# 33          C132       P034  Deodorant Stick  Men's Care  BrandF1    9.0
# 34          C132       P035       Hair Serum   Hair Care  BrandG1   18.0
# 35          C132       P036      Body Butter   Body Care  BrandH1   20.0
#
#      attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 33    Size: 75g                   6        2      0.333333      0.333333
# 34  Size: 100ml                   8        1      1.000000      0.000000
# 35  Size: 200ml                   5        4      0.000000      1.000000
#
#     combined_score
# 33        0.333333
# 34        0.500000
# 35        0.500000
# anchor_product - consultant_id                C132
# product_id                   P035
# product_name           Hair Serum
# category                Hair Care
# brand                     BrandG1
# price                        18.0
# attributes            Size: 100ml
# purchase_frequency              8
# recency                         1
# normalized_f                  1.0
# normalized_r                  0.0
# combined_score                0.5
# Name: 34, dtype: object
# bundle - [consultant_id                C132
# product_id                   P035
# product_name           Hair Serum
# category                Hair Care
# brand                     BrandG1
# price                        18.0
# attributes            Size: 100ml
# purchase_frequency              8
# recency                         1
# normalized_f                  1.0
# normalized_r                  0.0
# combined_score                0.5
# Name: 34, dtype: object, consultant_id                    C132
# product_id                       P034
# product_name          Deodorant Stick
# category                   Men's Care
# brand                         BrandF1
# price                             9.0
# attributes                  Size: 75g
# purchase_frequency                  6
# recency                             2
# normalized_f                      1.0
# normalized_r                      0.0
# combined_score                    0.5
# category_score                      1
# business_score               0.884246
# score                        0.953699
# Name: 33, dtype: object]
# Generating bundles for Consultant C133
# unique_bundle_id - C133_Bundle_1
# group -    consultant_id product_id       product_name    category    brand  price  \
# 36          C133       P037           Lip Tint      Makeup  BrandI1   16.0
# 37          C133       P038  Exfoliating Scrub    Skincare  BrandJ1   19.0
# 38          C133       P039       Shaving Foam  Men's Care  BrandK1   11.0
#
#       attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 36  Shade: Coral                   7        3           0.5      0.333333
# 37   Size: 150ml                   6        5           0.0      1.000000
# 38   Size: 200ml                   8        2           1.0      0.000000
#
#     combined_score
# 36        0.416667
# 37        0.500000
# 38        0.500000
# anchor_product - consultant_id                      C133
# product_id                         P038
# product_name          Exfoliating Scrub
# category                       Skincare
# brand                           BrandJ1
# price                              19.0
# attributes                  Size: 150ml
# purchase_frequency                    6
# recency                               5
# normalized_f                        0.0
# normalized_r                        1.0
# combined_score                      0.5
# Name: 37, dtype: object
# bundle - [consultant_id                      C133
# product_id                         P038
# product_name          Exfoliating Scrub
# category                       Skincare
# brand                           BrandJ1
# price                              19.0
# attributes                  Size: 150ml
# purchase_frequency                    6
# recency                               5
# normalized_f                        0.0
# normalized_r                        1.0
# combined_score                      0.5
# Name: 37, dtype: object, consultant_id                 C133
# product_id                    P039
# product_name          Shaving Foam
# category                Men's Care
# brand                      BrandK1
# price                         11.0
# attributes             Size: 200ml
# purchase_frequency               8
# recency                          2
# normalized_f                   1.0
# normalized_r                   0.0
# combined_score                 0.5
# category_score                   1
# business_score            0.800281
# score                     0.920113
# Name: 38, dtype: object]
# unique_bundle_id - C133_Bundle_2
# group -    consultant_id product_id       product_name    category    brand  price  \
# 36          C133       P037           Lip Tint      Makeup  BrandI1   16.0
# 37          C133       P038  Exfoliating Scrub    Skincare  BrandJ1   19.0
# 38          C133       P039       Shaving Foam  Men's Care  BrandK1   11.0
#
#       attributes  purchase_frequency  recency  normalized_f  normalized_r  \
# 36  Shade: Coral                   7        3           0.5      0.333333
# 37   Size: 150ml                   6        5           0.0      1.000000
# 38   Size: 200ml                   8        2           1.0      0.000000
#
#     combined_score
# 36        0.416667
# 37        0.500000
# 38        0.500000
# anchor_product - consultant_id                      C133
# product_id                         P038
# product_name          Exfoliating Scrub
# category                       Skincare
# brand                           BrandJ1
# price                              19.0
# attributes                  Size: 150ml
# purchase_frequency                    6
# recency                               5
# normalized_f                        0.0
# normalized_r                        1.0
# combined_score                      0.5
# Name: 37, dtype: object
# bundle - [consultant_id                      C133
# product_id                         P038
# product_name          Exfoliating Scrub
# category                       Skincare
# brand                           BrandJ1
# price                              19.0
# attributes                  Size: 150ml
# purchase_frequency                    6
# recency                               5
# normalized_f                        0.0
# normalized_r                        1.0
# combined_score                      0.5
# Name: 37, dtype: object, consultant_id                 C133
# product_id                    P039
# product_name          Shaving Foam
# category                Men's Care
# brand                      BrandK1
# price                         11.0
# attributes             Size: 200ml
# purchase_frequency               8
# recency                          2
# normalized_f                   1.0
# normalized_r                   0.0
# combined_score                 0.5
# category_score                   1
# business_score            0.984884
# score                     0.993954
# Name: 38, dtype: object]
# Generating bundles for Consultant C134
# unique_bundle_id - C134_Bundle_1
# group -    consultant_id product_id product_name category    brand  price  attributes  \
# 39          C134       P040  Face Primer   Makeup  BrandL1   26.0  Size: 50ml
#
#     purchase_frequency  recency  normalized_f  normalized_r  combined_score
# 39                   4        1             0             0             0.0
# anchor_product - consultant_id                C134
# product_id                   P040
# product_name          Face Primer
# category                   Makeup
# brand                     BrandL1
# price                        26.0
# attributes             Size: 50ml
# purchase_frequency              4
# recency                         1
# normalized_f                    0
# normalized_r                    0
# combined_score                0.0
# Name: 39, dtype: object
# bundle - [consultant_id                C134
# product_id                   P040
# product_name          Face Primer
# category                   Makeup
# brand                     BrandL1
# price                        26.0
# attributes             Size: 50ml
# purchase_frequency              4
# recency                         1
# normalized_f                    0
# normalized_r                    0
# combined_score                0.0
# Name: 39, dtype: object]
# unique_bundle_id - C134_Bundle_2
# group -    consultant_id product_id product_name category    brand  price  attributes  \
# 39          C134       P040  Face Primer   Makeup  BrandL1   26.0  Size: 50ml
#
#     purchase_frequency  recency  normalized_f  normalized_r  combined_score
# 39                   4        1             0             0             0.0
# anchor_product - consultant_id                C134
# product_id                   P040
# product_name          Face Primer
# category                   Makeup
# brand                     BrandL1
# price                        26.0
# attributes             Size: 50ml
# purchase_frequency              4
# recency                         1
# normalized_f                    0
# normalized_r                    0
# combined_score                0.0
# Name: 39, dtype: object
# bundle - [consultant_id                C134
# product_id                   P040
# product_name          Face Primer
# category                   Makeup
# brand                     BrandL1
# price                        26.0
# attributes             Size: 50ml
# purchase_frequency              4
# recency                         1
# normalized_f                    0
# normalized_r                    0
# combined_score                0.0
# Name: 39, dtype: object]

# %%
# Save the final bundles to CSV
save_bundle_to_csv(bundles, output_csv)
