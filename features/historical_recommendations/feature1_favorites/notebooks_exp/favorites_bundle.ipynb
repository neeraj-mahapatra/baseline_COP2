# %%
import pandas as pd
import random

# random.seed()  # Reseed the generator for more randomness

alpha = 0.4  
beta = 0.6   
purchasing_power = 100.0
k = 7   # size of bundles
C_max = 100.0  
theta = 1  
gamma = 0.25  
delta = 0.75
n_categories = 7  # max number of categories allowed per bundle
num_bundles = 2 # number of bundles
input_csv = "../src/data/files/processed_data_1000_C.csv"  
output_csv = "../src/data/files/bundle_data_1000_C.csv"  

def read_data_from_csv(csv_path):
    """Read product data from CSV."""
    return pd.read_csv(csv_path)

def save_bundle_to_csv(bundle, output_path):
    """Save the final bundle to a CSV file."""
    bundle_df = pd.DataFrame(bundle)
    bundle_df.to_csv(output_path, index=False)

def normalize(value, min_value, max_value):
    """Normalize the value to a common scale between 0 and 1."""
    if min_value == max_value:
        return 0
    return (value - min_value) / (max_value - min_value)

def calculate_combined_score(df, alpha, beta):
    """Calculate combined score using purchase frequency and recency."""
    min_f = df['purchase_frequency'].min()
    max_f = df['purchase_frequency'].max()
    min_r = df['recency'].min()
    max_r = df['recency'].max()
    
    df = df.copy()  # Ensure we're working with a copy
    df['normalized_f'] = df['purchase_frequency'].apply(lambda x: normalize(x, min_f, max_f))
    df['normalized_r'] = df['recency'].apply(lambda x: normalize(x, min_r, max_r))
    
    df['combined_score'] = (alpha * df['normalized_f']) + (beta * df['normalized_r'])
    return df

def select_anchor_product(df):
    """Select the anchor product based on the highest combined score."""
    return df.loc[df['combined_score'].idxmax()]

def generate_candidates(bundle, df):
    """Exclude products already in the bundle."""
    bundle_product_ids = {p['product_id'] for p in bundle}
    candidates = df[~df['product_id'].isin(bundle_product_ids)]
    return candidates

def score_candidates(candidates, bundle, gamma, delta):
    """Score candidates based on category and business rules."""
    def category_score(p):
        # Score is 1 if product's category is not in current bundle
        return 1 if p['category'] not in [b['category'] for b in bundle] else 0

    def business_score(p):
        val = random.randint(0, 3)
        print(f"Business Score Debug: product_id={p['product_id']} category={p['category']} score={val}")
        return val

    candidates = candidates.copy()
    candidates['category_score'] = candidates.apply(category_score, axis=1)
    candidates['business_score'] = candidates.apply(business_score, axis=1)
    candidates['score'] = gamma * candidates['category_score'] + delta * candidates['business_score']

    print("Candidate Categories:", candidates['category'].unique())
    print(candidates[['product_id', 'category', 'category_score', 'business_score', 'score']])
    return candidates


def build_bundle(df, anchor_product, purchasing_power, alpha, beta, k, C_max, theta, gamma, delta, n_categories):
    """
    Build a bundle that can contain up to n_categories categories.
    """
    bundle = [anchor_product]
    current_total_cost = anchor_product['price']
    categories_in_bundle = {anchor_product['category']}

    # Generate and score candidates
    candidates = generate_candidates(bundle, df)
    candidates = score_candidates(candidates, bundle, gamma, delta)

    # Filter candidates based on price constraint
    candidates = candidates[candidates['price'] <= theta * C_max]

    # Sort candidates by score in descending order for efficient selection
    candidates = candidates.sort_values(by='score', ascending=False)

    # Iterate through candidates to build the bundle
    for _, candidate in candidates.iterrows():
        if len(bundle) >= k:
            break  # Stop if bundle size is reached

        candidate_category = candidate['category']
        price = candidate['price']

        # If candidate category is new and within allowed category limit
        if candidate_category not in categories_in_bundle:
            if len(categories_in_bundle) < n_categories and current_total_cost + price <= C_max:
                bundle.append(candidate)
                current_total_cost += price
                categories_in_bundle.add(candidate_category)
        else:
            # Category already present in the bundle
            if current_total_cost + price <= C_max:
                bundle.append(candidate)
                current_total_cost += price

    # Ensure that bundles with a single product are not allowed
    if len(bundle) < 2:
        return []

    return bundle

# Read data from CSV
df = read_data_from_csv(input_csv)

bundles = []

# Iterate over each consultant
for consultant_id, group in df.groupby('consultant_id'):
    print(f"Generating bundles for Consultant {consultant_id}")
    
    # Use the average_purchasing_power column as C_max
    consultant_C_max = group['average_purchasing_power'].iloc[0]
    print(f"Average spending - {consultant_C_max}")
    
    for bundle_id in range(num_bundles):  # Generate 'num_bundles' bundles for each consultant
        unique_bundle_id = f"{consultant_id}_Bundle_{bundle_id + 1}"
        print(f"unique_bundle_id - {unique_bundle_id}")
        
        # Calculate combined score
        group_scored = calculate_combined_score(group, alpha, beta)
        
        # Select anchor product
        anchor_product = select_anchor_product(group_scored)

        # Build the bundle using average spending as C_max
        bundle = build_bundle(group_scored, anchor_product, purchasing_power, alpha, beta, k, consultant_C_max, theta, gamma, delta, n_categories)
        
        # Skip empty bundles or bundles with a single product
        if len(bundle) < 2:
            continue

        # Calculate bundle score as the average of combined scores
        bundle_score = sum([product['combined_score'] for product in bundle]) / len(bundle)

        # Save bundle details
        for idx, product in enumerate(bundle):
            product_copy = product.copy()
            product_copy['consultant_id'] = consultant_id
            product_copy['bundle_id'] = unique_bundle_id
            product_copy['is_anchor'] = 1 if idx == 0 else 0
            product_copy['bundle_score'] = bundle_score  # Add bundle score to each product in the bundle
            
            # Include the intermediate scores if they exist in product
            if 'category_score' in product:
                product_copy['category_score'] = product['category_score']
            if 'business_score' in product:
                product_copy['business_score'] = product['business_score']
            if 'score' in product:
                product_copy['selection_score'] = product['score']

            bundles.append(product_copy)

# Save the final bundles to CSV
save_bundle_to_csv(bundles, output_csv)
# Out:
# Generating bundles for Consultant 3441296
# Average spending - 430.195
# unique_bundle_id - 3441296_Bundle_1
# Business Score Debug: product_id=200090349 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200095864 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200107183 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108045 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200095159 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200106440 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200107144 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200108160 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200100407 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200096220 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200095159 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200106488 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200106569 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200094217 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200091709 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200083902 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210100298 category=PROMOCION USUARIOS score=2
# Business Score Debug: product_id=210100527 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115454 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200112529 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200089498 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200078924 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200117468 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200103452 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200106556 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115014 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210107061 category=BIJOUTERIE score=2
# Business Score Debug: product_id=210107062 category=BIJOUTERIE score=0
# Business Score Debug: product_id=210103911 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200103027 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200085822 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200099702 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200112353 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200103394 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200112352 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200089508 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200116225 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200112355 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200116439 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=200115484 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200106650 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200112065 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200118321 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200112748 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210098881 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210096207 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200097947 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210098785 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200115515 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200089498 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=210095652 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200092742 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210105321 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200089507 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200090400 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200110339 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200110329 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200115053 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200115274 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210105017 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200106356 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200095170 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200103716 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210095971 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200106605 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200064341 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200092742 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200107337 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210099191 category=RELOJES score=1
# Business Score Debug: product_id=200113955 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210098499 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095430 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210104205 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200036215 category=ACCESORIOS COSMETICOS score=3
# Business Score Debug: product_id=200112295 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210106658 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200112304 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200107184 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200106556 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200108409 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200110344 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200086432 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210102544 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200110347 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200110331 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210095652 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200078931 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200112353 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105655 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200106360 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200112295 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210100531 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200095420 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200103449 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200095382 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200112361 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210105919 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200087251 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200103719 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200090349 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200085822 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200107850 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200110734 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200110734 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200112361 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200094217 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200110337 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200112748 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210099817 category=ACCESORIOS COSMETICOS score=0
# Business Score Debug: product_id=200088133 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200103020 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200108160 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200106661 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200110958 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210098499 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108892 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200098698 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210096702 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200091727 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210103963 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200078931 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200109890 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200092333 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200086399 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200111234 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200105011 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210102060 category=HOGAR score=3
# Business Score Debug: product_id=200112314 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200096220 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200096218 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200090349 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210098464 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210097405 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200115451 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200115453 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200113721 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200105207 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210100529 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210100495 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200103448 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200088133 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200086432 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106445 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200117564 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=210106468 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200115402 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210095975 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210103488 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200095465 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200108911 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200106565 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200064310 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200072913 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210099819 category=PROMOCION USUARIOS score=1
# Business Score Debug: product_id=200092744 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200108892 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200108674 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105079 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210103127 category=RELOJES score=2
# Business Score Debug: product_id=200100407 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210092742 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210104902 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=200106452 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200115454 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200110328 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115453 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200110329 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200114125 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200110328 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200083952 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200115399 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200103028 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210104074 category=RELOJES score=1
# Business Score Debug: product_id=200100926 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200115398 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108160 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200112748 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210093312 category=ACCESORIOS COSMETICOS score=3
# Business Score Debug: product_id=210101749 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200064341 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200082652 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210103944 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200110328 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200101061 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=210096264 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210100498 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200096220 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200090346 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200105190 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200112306 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200089488 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200114550 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200113952 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200106462 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200090337 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210092742 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200089488 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=200106455 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200116374 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200088133 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200108045 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210103922 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200107184 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200105217 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200106488 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200102292 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200036215 category=ACCESORIOS COSMETICOS score=1
# Business Score Debug: product_id=200099702 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200106461 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200109610 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200101110 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200093883 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200109163 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210105453 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200109610 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200115170 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200105125 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200106852 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200115160 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200115515 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=210102594 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200114988 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200115403 category=MAQUILLAJE score=0
# Candidate Categories: ['CUIDADO PERSONAL' 'FRAGANCIAS' 'MAQUILLAJE' 'TRATAMIENTO CORPORAL'
#  'TRATAMIENTO FACIAL' 'PROMOCION USUARIOS' 'BIJOUTERIE' 'RELOJES'
#  'ACCESORIOS COSMETICOS' 'COMPLEMENTOS' 'HOGAR']
#        product_id              category  category_score  business_score  score
# 5       200090349      CUIDADO PERSONAL               1               1   1.00
# 324     200095864            FRAGANCIAS               0               3   2.25
# 450     200107183            MAQUILLAJE               1               0   0.25
# 788     200108045  TRATAMIENTO CORPORAL               1               1   1.00
# 791     200095159      CUIDADO PERSONAL               1               0   0.25
# ...           ...                   ...             ...             ...    ...
# 35529   200115515    TRATAMIENTO FACIAL               1               2   1.75
# 35532   210102594          COMPLEMENTOS               1               0   0.25
# 35625   200039855            FRAGANCIAS               0               2   1.50
# 35929   200114988  TRATAMIENTO CORPORAL               1               0   0.25
# 36154   200115403            MAQUILLAJE               1               0   0.25
#
# [260 rows x 5 columns]
# unique_bundle_id - 3441296_Bundle_2
# Business Score Debug: product_id=200090349 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200095864 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200107183 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108045 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200095159 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200106440 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200107144 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108160 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200100407 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200096220 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200095159 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200106488 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200106569 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200094217 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200091709 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200083902 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210100298 category=PROMOCION USUARIOS score=1
# Business Score Debug: product_id=210100527 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115454 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200112529 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200089498 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200078924 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200117468 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200103452 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106556 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200115014 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210107061 category=BIJOUTERIE score=3
# Business Score Debug: product_id=210107062 category=BIJOUTERIE score=3
# Business Score Debug: product_id=210103911 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200103027 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200085822 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200099702 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200112353 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200103394 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200112352 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200089508 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200116225 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200112355 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200116439 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200115484 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200106650 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200112065 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200118321 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200112748 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210098881 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210096207 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200097947 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210098785 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200115515 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200089498 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=210095652 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200092742 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210105321 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200089507 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200090400 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200110339 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200110329 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200115053 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115274 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210105017 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200106356 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200095170 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200103716 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210095971 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200106605 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200064341 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200092742 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200107337 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210099191 category=RELOJES score=2
# Business Score Debug: product_id=200113955 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210098499 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200095430 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210104205 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200036215 category=ACCESORIOS COSMETICOS score=0
# Business Score Debug: product_id=200112295 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210106658 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200112304 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200107184 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200106556 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200108409 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200110344 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200086432 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210102544 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200110347 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200110331 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210095652 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200078931 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200112353 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200105655 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200106360 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200112295 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210100531 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095420 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200103449 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200095382 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200112361 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210105919 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200087251 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200103719 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200090349 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200085822 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200107850 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200110734 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200110734 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200112361 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200094217 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200110337 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200112748 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210099817 category=ACCESORIOS COSMETICOS score=3
# Business Score Debug: product_id=200088133 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200103020 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200108160 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200106661 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200110958 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210098499 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108892 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200098698 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210096702 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200091727 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210103963 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200078931 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200109890 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200092333 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200086399 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200111234 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200105011 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210102060 category=HOGAR score=1
# Business Score Debug: product_id=200112314 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200096220 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200096218 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200090349 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210098464 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210097405 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200115451 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200115453 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200113721 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200105207 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=3
# Business Score Debug: product_id=210100529 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210100495 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200103448 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200088133 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200086432 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106445 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200117564 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=210106468 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200115402 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210095975 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210103488 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200095465 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200108911 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200106565 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200064310 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200072913 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210099819 category=PROMOCION USUARIOS score=2
# Business Score Debug: product_id=200092744 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200108892 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200108674 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105079 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210103127 category=RELOJES score=1
# Business Score Debug: product_id=200100407 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210092742 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210104902 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200106452 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200115454 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200110328 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200115453 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200110329 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200114125 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200110328 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200083952 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200115399 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200095931 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200103028 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210104074 category=RELOJES score=0
# Business Score Debug: product_id=200100926 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200115398 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200108160 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200112748 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210093312 category=ACCESORIOS COSMETICOS score=2
# Business Score Debug: product_id=210101749 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200064341 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200082652 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210103944 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200110328 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200101061 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=210096264 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210100498 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200105041 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200096220 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200090346 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200105190 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200112306 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200089488 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200114550 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=200113952 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200106462 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200090337 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=210092742 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200089488 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200106455 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200116374 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200088133 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200108045 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=0
# Business Score Debug: product_id=210103922 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200107184 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200105217 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200106488 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200102292 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200036215 category=ACCESORIOS COSMETICOS score=3
# Business Score Debug: product_id=200099702 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106461 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200109610 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200101110 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=200093883 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200109163 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210105453 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200109610 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200115170 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200105125 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200106852 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200115160 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200115515 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=210102594 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200114988 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200115403 category=MAQUILLAJE score=1
# Candidate Categories: ['CUIDADO PERSONAL' 'FRAGANCIAS' 'MAQUILLAJE' 'TRATAMIENTO CORPORAL'
#  'TRATAMIENTO FACIAL' 'PROMOCION USUARIOS' 'BIJOUTERIE' 'RELOJES'
#  'ACCESORIOS COSMETICOS' 'COMPLEMENTOS' 'HOGAR']
#        product_id              category  category_score  business_score  score
# 5       200090349      CUIDADO PERSONAL               1               3   2.50
# 324     200095864            FRAGANCIAS               0               0   0.00
# 450     200107183            MAQUILLAJE               1               0   0.25
# 788     200108045  TRATAMIENTO CORPORAL               1               0   0.25
# 791     200095159      CUIDADO PERSONAL               1               2   1.75
# ...           ...                   ...             ...             ...    ...
# 35529   200115515    TRATAMIENTO FACIAL               1               0   0.25
# 35532   210102594          COMPLEMENTOS               1               3   2.50
# 35625   200039855            FRAGANCIAS               0               2   1.50
# 35929   200114988  TRATAMIENTO CORPORAL               1               0   0.25
# 36154   200115403            MAQUILLAJE               1               1   1.00
#
# [260 rows x 5 columns]
# Generating bundles for Consultant 4623541
# Average spending - 430.195
# unique_bundle_id - 4623541_Bundle_1
# Business Score Debug: product_id=200102650 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200102351 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200110005 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200100052 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200106604 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200102351 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200110953 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210102625 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=210098828 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200107358 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200101587 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200105125 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200089509 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200106029 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200102430 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200099339 category=MUESTRAS COSMETICOS score=1
# Business Score Debug: product_id=200112752 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200082678 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200095964 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200109263 category=TRATAMIENTO FACIAL score=3
# Business Score Debug: product_id=210102065 category=HOGAR score=1
# Business Score Debug: product_id=200103727 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108408 category=FRAGANCIAS score=1
# Business Score Debug: product_id=210098190 category=BIJOUTERIE score=0
# Business Score Debug: product_id=200103338 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200112233 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200107183 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200107360 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200107365 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200105984 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200094826 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200102110 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210095243 category=LENTES score=0
# Business Score Debug: product_id=200094840 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200102092 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=2
# Business Score Debug: product_id=210098551 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210100407 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200091357 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200112474 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200094830 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200105985 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200094876 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210096207 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200097895 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=210102442 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210100617 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200103354 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200106604 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108674 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200100593 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200106556 category=MAQUILLAJE score=0
# Business Score Debug: product_id=210101252 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=200105035 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200105178 category=TRATAMIENTO CORPORAL score=1
# Business Score Debug: product_id=200112231 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200102110 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200109169 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200107373 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200107349 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210101561 category=BIJOUTERIE score=3
# Business Score Debug: product_id=210101264 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=210100628 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200112478 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108892 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=210092742 category=MAQUILLAJE score=2
# Business Score Debug: product_id=210095652 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200106556 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200091875 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108674 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200091455 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200108807 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200107367 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200101369 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200095663 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210102042 category=COMPLEMENTOS score=2
# Business Score Debug: product_id=200106290 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200086399 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200086399 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200109443 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200106488 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200112062 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200105195 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200107361 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200094836 category=MAQUILLAJE score=1
# Business Score Debug: product_id=210094410 category=ACCESORIOS COSMETICOS score=2
# Business Score Debug: product_id=210102551 category=RELOJES score=2
# Business Score Debug: product_id=200102430 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200107350 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200103920 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200107360 category=MAQUILLAJE score=0
# Business Score Debug: product_id=200064341 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=210101285 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=210101284 category=COMPLEMENTOS score=0
# ...
#  'FRAGANCIAS' 'MAQUILLAJE' 'TRATAMIENTO CORPORAL' 'MUESTRAS COSMETICOS'
#  'VARIOS' 'RELOJES' 'ACCESORIOS COSMETICOS']
#        product_id               category  category_score  business_score  \
# 3852    210106115           COMPLEMENTOS               1               0
# 3915    210102079           COMPLEMENTOS               1               1
# 4006    200105125       CUIDADO PERSONAL               0               0
# 4007    200105180       CUIDADO PERSONAL               0               2
# 4011    200115689     TRATAMIENTO FACIAL               1               1
# 4128    210106556             BIJOUTERIE               1               3
# 4152    200108160             FRAGANCIAS               1               2
# 7781    200099047             FRAGANCIAS               1               0
# 8101    200089168             FRAGANCIAS               1               3
# 8103    200114054             MAQUILLAJE               1               2
# 8245    200102351             MAQUILLAJE               1               0
# 8271    210097089       CUIDADO PERSONAL               0               0
# 12001   200098673             FRAGANCIAS               1               1
# 12002   200109566             MAQUILLAJE               1               3
# 12171   210106129           COMPLEMENTOS               1               2
# 12187   210097089       CUIDADO PERSONAL               0               1
# 12642   200115403             MAQUILLAJE               1               1
# 12645   200105017             FRAGANCIAS               1               2
# 12646   200116439   TRATAMIENTO CORPORAL               1               1
# 12647   200112299             MAQUILLAJE               1               0
# 12680   200116476     TRATAMIENTO FACIAL               1               1
# 12681   200116439   TRATAMIENTO CORPORAL               1               2
# 12682   200106349             FRAGANCIAS               1               1
# 12730   200108674       CUIDADO PERSONAL               0               2
# 12734   200113372     TRATAMIENTO FACIAL               1               3
# 12737   210105843             BIJOUTERIE               1               2
# 12738   200111319             FRAGANCIAS               1               1
# 12739   200105188       CUIDADO PERSONAL               0               2
# 12740   200113951     TRATAMIENTO FACIAL               1               0
# 17638   210106559             BIJOUTERIE               1               3
# 17840   200106567             MAQUILLAJE               1               1
# 17932   200108674       CUIDADO PERSONAL               0               2
# 21774   200109509    MUESTRAS COSMETICOS               1               3
# 22034   200106668             MAQUILLAJE               1               2
# 22042   200103025       CUIDADO PERSONAL               0               0
# 22168   210096235             MAQUILLAJE               1               1
# 22169   200039855             FRAGANCIAS               1               3
# 22176   200086399             FRAGANCIAS               1               3
# 22337   200114085    MUESTRAS COSMETICOS               1               0
# 22338   200089488   TRATAMIENTO CORPORAL               1               1
# 26432   200114911             FRAGANCIAS               1               3
# 26434   200118627                 VARIOS               1               3
# 26543   200118378             MAQUILLAJE               1               3
# 26546   200102348             MAQUILLAJE               1               0
# 26955   200117564     TRATAMIENTO FACIAL               1               3
# 26956   200115454       CUIDADO PERSONAL               0               3
# 30765   210107682             BIJOUTERIE               1               3
# 30768   210104222                RELOJES               1               3
# 30770   210099817  ACCESORIOS COSMETICOS               1               0
# 30837   200103441       CUIDADO PERSONAL               0               3
# 31143   200109509    MUESTRAS COSMETICOS               1               3
# 31147   210106583             BIJOUTERIE               1               3
# 31148   200112530   TRATAMIENTO CORPORAL               1               2
# 35894   210107494           COMPLEMENTOS               1               0
# 36058   200095430       CUIDADO PERSONAL               0               2
# 36059   200085860       CUIDADO PERSONAL               0               3
# 36063   200113296             MAQUILLAJE               1               2
# 36250   200118227             MAQUILLAJE               1               2
# 36254   200082687       CUIDADO PERSONAL               0               0
# 36308   200113410   TRATAMIENTO CORPORAL               1               3
#
#        score
# 3852    0.25
# 3915    1.00
# 4006    0.00
# 4007    1.50
# 4011    1.00
# 4128    2.50
# 4152    1.75
# 7781    0.25
# 8101    2.50
# 8103    1.75
# 8245    0.25
# 8271    0.00
# 12001   1.00
# 12002   2.50
# 12171   1.75
# 12187   0.75
# 12642   1.00
# 12645   1.75
# 12646   1.00
# 12647   0.25
# 12680   1.00
# 12681   1.75
# 12682   1.00
# 12730   1.50
# 12734   2.50
# 12737   1.75
# 12738   1.00
# 12739   1.50
# 12740   0.25
# 17638   2.50
# 17840   1.00
# 17932   1.50
# 21774   2.50
# 22034   1.75
# 22042   0.00
# 22168   1.00
# 22169   2.50
# 22176   2.50
# 22337   0.25
# 22338   1.00
# 26432   2.50
# 26434   2.50
# 26543   2.50
# 26546   0.25
# 26955   2.50
# 26956   2.25
# 30765   2.50
# 30768   2.50
# 30770   0.25
# 30837   2.25
# 31143   2.50
# 31147   2.50
# 31148   1.75
# 35894   0.25
# 36058   1.50
# 36059   2.25
# 36063   1.75
# 36250   1.75
# 36254   0.00
# 36308   2.50
# unique_bundle_id - 52567297_Bundle_2
# Business Score Debug: product_id=210106115 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=210102079 category=COMPLEMENTOS score=0
# Business Score Debug: product_id=200105125 category=CUIDADO PERSONAL score=1
# Business Score Debug: product_id=200105180 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200115689 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=210106556 category=BIJOUTERIE score=2
# Business Score Debug: product_id=200108160 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200099047 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200089168 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200114054 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200102351 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210097089 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200098673 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200109566 category=MAQUILLAJE score=3
# Business Score Debug: product_id=210106129 category=COMPLEMENTOS score=1
# Business Score Debug: product_id=210097089 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200115403 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200105017 category=FRAGANCIAS score=0
# Business Score Debug: product_id=200116439 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200112299 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200116476 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=200116439 category=TRATAMIENTO CORPORAL score=3
# Business Score Debug: product_id=200106349 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200108674 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200113372 category=TRATAMIENTO FACIAL score=1
# Business Score Debug: product_id=210105843 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200111319 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200105188 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200113951 category=TRATAMIENTO FACIAL score=0
# Business Score Debug: product_id=210106559 category=BIJOUTERIE score=3
# Business Score Debug: product_id=200106567 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200108674 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200109509 category=MUESTRAS COSMETICOS score=3
# Business Score Debug: product_id=200106668 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200103025 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=210096235 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200039855 category=FRAGANCIAS score=2
# Business Score Debug: product_id=200086399 category=FRAGANCIAS score=3
# Business Score Debug: product_id=200114085 category=MUESTRAS COSMETICOS score=1
# Business Score Debug: product_id=200089488 category=TRATAMIENTO CORPORAL score=0
# Business Score Debug: product_id=200114911 category=FRAGANCIAS score=1
# Business Score Debug: product_id=200118627 category=VARIOS score=1
# Business Score Debug: product_id=200118378 category=MAQUILLAJE score=1
# Business Score Debug: product_id=200102348 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200117564 category=TRATAMIENTO FACIAL score=2
# Business Score Debug: product_id=200115454 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=210107682 category=BIJOUTERIE score=2
# Business Score Debug: product_id=210104222 category=RELOJES score=3
# Business Score Debug: product_id=210099817 category=ACCESORIOS COSMETICOS score=1
# Business Score Debug: product_id=200103441 category=CUIDADO PERSONAL score=2
# Business Score Debug: product_id=200109509 category=MUESTRAS COSMETICOS score=2
# Business Score Debug: product_id=210106583 category=BIJOUTERIE score=1
# Business Score Debug: product_id=200112530 category=TRATAMIENTO CORPORAL score=2
# Business Score Debug: product_id=210107494 category=COMPLEMENTOS score=3
# Business Score Debug: product_id=200095430 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200085860 category=CUIDADO PERSONAL score=0
# Business Score Debug: product_id=200113296 category=MAQUILLAJE score=2
# Business Score Debug: product_id=200118227 category=MAQUILLAJE score=3
# Business Score Debug: product_id=200082687 category=CUIDADO PERSONAL score=3
# Business Score Debug: product_id=200113410 category=TRATAMIENTO CORPORAL score=3
# Candidate Categories: ['COMPLEMENTOS' 'CUIDADO PERSONAL' 'TRATAMIENTO FACIAL' 'BIJOUTERIE'
#  'FRAGANCIAS' 'MAQUILLAJE' 'TRATAMIENTO CORPORAL' 'MUESTRAS COSMETICOS'
#  'VARIOS' 'RELOJES' 'ACCESORIOS COSMETICOS']
#        product_id               category  category_score  business_score  \
# 3852    210106115           COMPLEMENTOS               1               3
# 3915    210102079           COMPLEMENTOS               1               0
# 4006    200105125       CUIDADO PERSONAL               0               1
# 4007    200105180       CUIDADO PERSONAL               0               3
# 4011    200115689     TRATAMIENTO FACIAL               1               1
# 4128    210106556             BIJOUTERIE               1               2
# 4152    200108160             FRAGANCIAS               1               1
# 7781    200099047             FRAGANCIAS               1               3
# 8101    200089168             FRAGANCIAS               1               1
# 8103    200114054             MAQUILLAJE               1               3
# 8245    200102351             MAQUILLAJE               1               3
# 8271    210097089       CUIDADO PERSONAL               0               2
# 12001   200098673             FRAGANCIAS               1               1
# 12002   200109566             MAQUILLAJE               1               3
# 12171   210106129           COMPLEMENTOS               1               1
# 12187   210097089       CUIDADO PERSONAL               0               0
# 12642   200115403             MAQUILLAJE               1               2
# 12645   200105017             FRAGANCIAS               1               0
# 12646   200116439   TRATAMIENTO CORPORAL               1               3
# 12647   200112299             MAQUILLAJE               1               1
# 12680   200116476     TRATAMIENTO FACIAL               1               0
# 12681   200116439   TRATAMIENTO CORPORAL               1               3
# 12682   200106349             FRAGANCIAS               1               3
# 12730   200108674       CUIDADO PERSONAL               0               2
# 12734   200113372     TRATAMIENTO FACIAL               1               1
# 12737   210105843             BIJOUTERIE               1               3
# 12738   200111319             FRAGANCIAS               1               2
# 12739   200105188       CUIDADO PERSONAL               0               2
# 12740   200113951     TRATAMIENTO FACIAL               1               0
# 17638   210106559             BIJOUTERIE               1               3
# 17840   200106567             MAQUILLAJE               1               1
# 17932   200108674       CUIDADO PERSONAL               0               3
# 21774   200109509    MUESTRAS COSMETICOS               1               3
# 22034   200106668             MAQUILLAJE               1               1
# 22042   200103025       CUIDADO PERSONAL               0               3
# 22168   210096235             MAQUILLAJE               1               2
# 22169   200039855             FRAGANCIAS               1               2
# 22176   200086399             FRAGANCIAS               1               3
# 22337   200114085    MUESTRAS COSMETICOS               1               1
# 22338   200089488   TRATAMIENTO CORPORAL               1               0
# 26432   200114911             FRAGANCIAS               1               1
# 26434   200118627                 VARIOS               1               1
# 26543   200118378             MAQUILLAJE               1               1
# 26546   200102348             MAQUILLAJE               1               2
# 26955   200117564     TRATAMIENTO FACIAL               1               2
# 26956   200115454       CUIDADO PERSONAL               0               2
# 30765   210107682             BIJOUTERIE               1               2
# 30768   210104222                RELOJES               1               3
# 30770   210099817  ACCESORIOS COSMETICOS               1               1
# 30837   200103441       CUIDADO PERSONAL               0               2
# 31143   200109509    MUESTRAS COSMETICOS               1               2
# 31147   210106583             BIJOUTERIE               1               1
# 31148   200112530   TRATAMIENTO CORPORAL               1               2
# 35894   210107494           COMPLEMENTOS               1               3
# 36058   200095430       CUIDADO PERSONAL               0               0
# 36059   200085860       CUIDADO PERSONAL               0               0
# 36063   200113296             MAQUILLAJE               1               2
# 36250   200118227             MAQUILLAJE               1               3
# 36254   200082687       CUIDADO PERSONAL               0               3
# 36308   200113410   TRATAMIENTO CORPORAL               1               3
#
#        score
# 3852    2.50
# 3915    0.25
# 4006    0.75
# 4007    2.25
# 4011    1.00
# 4128    1.75
# 4152    1.00
# 7781    2.50
# 8101    1.00
# 8103    2.50
# 8245    2.50
# 8271    1.50
# 12001   1.00
# 12002   2.50
# 12171   1.00
# 12187   0.00
# 12642   1.75
# 12645   0.25
# 12646   2.50
# 12647   1.00
# 12680   0.25
# 12681   2.50
# 12682   2.50
# 12730   1.50
# 12734   1.00
# 12737   2.50
# 12738   1.75
# 12739   1.50
# 12740   0.25
# 17638   2.50
# 17840   1.00
# 17932   2.25
# 21774   2.50
# 22034   1.00
# 22042   2.25
# 22168   1.75
# 22169   1.75
# 22176   2.50
# 22337   1.00
# 22338   0.25
# 26432   1.00
# 26434   1.00
# 26543   1.00
# 26546   1.75
# 26955   1.75
# 26956   1.50
# 30765   1.75
# 30768   2.50
# 30770   1.00
# 30837   1.50
# 31143   1.75
# 31147   1.00
# 31148   1.75
# 35894   2.50
# 36058   0.00
# 36059   0.00
# 36063   1.75
# 36250   2.50
# 36254   2.25
# 36308   2.50
